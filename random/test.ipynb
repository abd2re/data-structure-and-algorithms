# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from guessers import *

# %%
data = {'mahou':mahouguesses,'big chungus':wahabguesses}

# %%
df = pd.DataFrame(data,index=listofnum)

# %%
df
# Out:
#     mahou  big chungus
# 1       7            4
# 2       6            3
# 3       7            7
# 4       5            6
# 5       6            7
# ..    ...          ...
# 95      7            7
# 96      5            6
# 97      7            7
# 98      6            3
# 99      7            5
#
# [99 rows x 2 columns]

# %%
df.plot.line(figsize=(25, 10))
# Out:
# <AxesSubplot:>

# %%
df.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df.to_excel('results.xlsx')
